# %%
import pandas as pd

df = pd.read_csv("/content/neu-boston-boys_2025-02-09_export.csv")

# %%
df
# Out:
#            Date                 Description    Category      Cost Currency  \
# 0    2024-08-15               Boston hotel        Hotel  49120.08      INR
# 1    2024-08-15     Atta paid Vishwajeet H.     Payment  16373.36      INR
# 2    2024-08-16  Aman R. paid Vishwajeet H.     Payment  16373.36      INR
# 3    2024-08-30                   TB dinner  Dining out   1470.00      INR
# 4    2024-08-30            Pain au chocolat     General    706.00      INR
# ..          ...                         ...         ...       ...      ...
# 358  2025-02-09               You know what     General     18.15      USD
# 359  2025-02-09                    Tomatoes     General      4.70      USD
# 360  2025-02-09                    Tropical     General     39.04      USD
# 361  2025-02-09               Total balance                            INR
# 362  2025-02-09               Total balance                            USD
#
#      Aman Rao  Vishwajeet Hogale  Suraj Patel M      Atta
# ...

# %%
df = df[df["Currency"] == 'USD']

# %%
df = df[df["Date"] > "2024-09-30" ]

# %%
df = df[~((df["Date"] > "2024-12-27") & (df["Date"] < "2025-01-03"))]

# %%
len(df["Date"].unique())
# Out:
# 97

# %%
df["Category"].unique()
# Out:
# array(['Groceries', 'Services', 'General', 'Rent', 'Payment',
#        'Dining out', 'Electronics', 'Bus/train', 'TV/Phone/Internet',
#        'Taxi', 'Home - Other', 'Electricity', 'Household supplies',
#        'Liquor', 'Entertainment - Other', 'Furniture', 'Insurance', ' '],
#       dtype=object)

# %%
df = df[~df["Category"].isin(['Rent', 'Furniture'])]

# %%
df["Category"].unique()
# Out:
# array(['Groceries', 'Services', 'General', 'Payment', 'Dining out',
#        'Electronics', 'Bus/train', 'TV/Phone/Internet', 'Taxi',
#        'Home - Other', 'Electricity', 'Household supplies', 'Liquor',
#        'Entertainment - Other', 'Insurance', ' '], dtype=object)

# %%
df.sort_values(by='Cost', ascending=False)
# Out:
#            Date      Description   Category   Cost Currency  Aman Rao  \
# 122  2024-10-16        Groceries  Groceries  99.17      USD     74.38
# 205  2024-12-03             Whey    General  98.47      USD     65.65
# 163  2024-11-10         Tropical    General  97.22      USD    -24.30
# 139  2024-10-29  Transaction fee    General   9.99      USD      7.49
# 304  2025-01-11             Milk  Groceries   9.58      USD      7.18
# ..          ...              ...        ...    ...      ...       ...
# 245  2024-12-21            Paani    General   1.89      USD      0.00
# 246  2024-12-22              Bus  Bus/train   1.70      USD      0.00
# 118  2024-10-11              Bus  Bus/train   1.70      USD      0.00
# 204  2024-12-01             Mint    General   1.49      USD     -0.38
# 362  2025-02-09    Total balance                        USD    194.63
#
#      Vishwajeet Hogale  Suraj Patel M    Atta
# 122             -24.80         -24.79  -24.79
# ...

# %%
df = df[~df["Description"].str.contains("paid", case=False, na=False)]

# %%
df
# Out:
#            Date          Description    Category   Cost Currency  Aman Rao  \
# 94   2024-10-01               Snacks   Groceries   7.78      USD      3.89
# 95   2024-10-01              Laundry    Services   6.00      USD      6.00
# 96   2024-10-01  Garba night tickets     General  32.00      USD     16.00
# 101  2024-10-01        Wash and dry      General   6.00      USD      6.00
# 102  2024-10-02             Coffee W  Dining out   5.89      USD      0.00
# ..          ...                  ...         ...    ...      ...       ...
# 357  2025-02-09                  Alc     General  51.48      USD     34.32
# 358  2025-02-09        You know what     General  18.15      USD      0.00
# 359  2025-02-09             Tomatoes     General   4.70      USD      0.00
# 360  2025-02-09             Tropical     General  39.04      USD     -9.76
# 362  2025-02-09        Total balance                         USD    194.63
#
#      Vishwajeet Hogale  Suraj Patel M    Atta
# ...

# %%
df["Category"].unique()
# Out:
# array(['Groceries', 'Services', 'General', 'Dining out', 'Electronics',
#        'Bus/train', 'TV/Phone/Internet', 'Taxi', 'Home - Other',
#        'Electricity', 'Household supplies', 'Liquor',
#        'Entertainment - Other', 'Insurance', ' '], dtype=object)

# %%
df.sort_values(by='Cost', ascending=False)
# Out:
#            Date      Description   Category   Cost Currency  Aman Rao  \
# 122  2024-10-16        Groceries  Groceries  99.17      USD     74.38
# 205  2024-12-03             Whey    General  98.47      USD     65.65
# 163  2024-11-10         Tropical    General  97.22      USD    -24.30
# 139  2024-10-29  Transaction fee    General   9.99      USD      7.49
# 355  2025-02-05             Milk  Groceries   9.58      USD     -2.39
# ..          ...              ...        ...    ...      ...       ...
# 245  2024-12-21            Paani    General   1.89      USD      0.00
# 246  2024-12-22              Bus  Bus/train   1.70      USD      0.00
# 118  2024-10-11              Bus  Bus/train   1.70      USD      0.00
# 204  2024-12-01             Mint    General   1.49      USD     -0.38
# 362  2025-02-09    Total balance                        USD    194.63
#
#      Vishwajeet Hogale  Suraj Patel M    Atta
# 122             -24.80         -24.79  -24.79
# ...

# %%
df = df[~df["Description"].str.contains("NYC", case=False, na=False)]

# %%
# Ensure 'Cost' column is numeric
df["Cost"] = pd.to_numeric(df["Cost"], errors="coerce")

# Ensure 'Date' column is in datetime format (if necessary)
df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# Now perform the calculation
average_cost_per_date = df["Cost"].sum() / len(df["Date"].unique())

print(average_cost_per_date/4)
# Out:
# 14.16020618556701
# <ipython-input-16-f50dd0789795>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cost"] = pd.to_numeric(df["Cost"], errors="coerce")
# <ipython-input-16-f50dd0789795>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"], errors="coerce")

# %%
# Ensure 'Date' is in datetime format
df["Date"] = pd.to_datetime(df["Date"])

# Convert 'Cost' to numeric
df["Cost"] = pd.to_numeric(df["Cost"], errors="coerce")

# Extract month
df["Month"] = df["Date"].dt.to_period("M")

# Calculate month-wise total expenditure
month_wise_expenditure = df.groupby("Month")["Cost"].sum()

# Divide by 6 for per person cost
month_wise_per_person = month_wise_expenditure / 4

# Print result
print("Month-wise per person cost:\n", month_wise_per_person.round(2))
# Out:
# Month-wise per person cost:
#  Month
# 2024-10    299.42
# 2024-11    341.69
# 2024-12    295.49
# 2025-01    319.15
# 2025-02    117.79
# Freq: M, Name: Cost, dtype: float64
# <ipython-input-17-107b94f35c74>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"])
# <ipython-input-17-107b94f35c74>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cost"] = pd.to_numeric(df["Cost"], errors="coerce")
# ...
